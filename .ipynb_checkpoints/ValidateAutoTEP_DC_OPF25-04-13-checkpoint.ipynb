# %% [markdown]
# # Today it was sunny

# %%
import pandas as pd
import pandapower as pp
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import copy
import copy
import pulp
import time
import pulp
import csv
import random

#MY CODE BASE
import GridFlowSmooth as flow 

datelabel = str(datetime.now())[2:10]

# %% [markdown]
# # PandaPower Solver as Reference
# "joint development of the research group of the Department for Sustainable Electrical Energy Systems (e2n), University of Kassel and the Department for Distribution System Operation at the Fraunhofer Institute for Energy Economics and Energy System Technology (IEE), Kassel."
# https://pandapower.readthedocs.io/en/latest/

# %%
def panda_DCOPF(gen_capacity = {1:150,2:0,3:0,4:0}, line_capacity = 100, 
                 susceptances = {(1,2):1500, (2,3):1500, (3,4):1500, (1,3):1500, (1,4):1500}, 
                 line_expansion_cost = 1000, buses = [1, 2, 3, 4], obj = 'cost', cut = False,
                 demands = {1: 30, 2: 20, 3: 20, 4: 20}, ac_lines = [(1, 2), (2,3), (3,4)], 
                 dc_lines = [], generation_cost = {1: 120}, printout = True):
    net = pp.create_empty_network()
    ## # BUSES # ##
    pd_buses = {}             
    for i in buses:
        pd_buses[i] = pp.create_bus(net, vn_kv=1, name=f"Bus {i}")
    ## # LINES # ##
    for fb, tb in ac_lines:
        pp.create_line_from_parameters(net, from_bus=pd_buses[fb], to_bus=pd_buses[tb], length_km=1,
                                       r_ohm_per_km=0, x_ohm_per_km=1/susceptances[(fb,tb)], c_nf_per_km=0,
                                       max_i_ka=1000, name=f"Line {fb}-{tb}")
    ## # LOADS # ##
    for i in demands:
        pp.create_load(net, bus=pd_buses[i], p_mw=demands[i], q_mvar=0, controllable=False, name=f"Load Bus {i}")
    pd_gens = {}
    ## # GENERATORS # ##
    slack_gen = np.min(list(generation_cost.keys()))
    for i in gen_capacity:
        if gen_capacity[i]>0:
            pd_gens[i] = pp.create_gen(net, bus=pd_buses[i], p_mw=0, vm_pu=1.02, min_p_mw=0, max_p_mw=gen_capacity[i],
                         controllable=True, name=f"Gen Bus {i}", slack = i==slack_gen )
    for i in pd_gens:
        pp.create_poly_cost(net, element=pd_gens[i], et="gen", cp1_eur_per_mw=generation_cost[i])
    # Run DC OPF
    out =pp.runopp(net, delta=1e-10, calculate_voltage_angles=True, trafo_model="pi")
    if printout:
        print("\n--- Generator Results ---")
        print(net.res_gen['p_mw'])
        
        print("\n--- Line Flow ---")
        print(net.res_line[["p_from_mw"]])
        
        print("\n--- Bus Voltage Angles (rad) ---")
        print(net.res_bus["va_degree"]*np.pi/180)
    return net

# %%
out, prob = flow.ACDC_TEP_OPF(gen_capacity = {1:150,2:0,3:0,4:0}, line_capacity = 100, 
                 susceptances = {(1,2):1500, (2,3):1500, (3,4):1500, (1,3):1500, (1,4):1500}, 
                 line_expansion_cost = 1000, buses = [1, 2, 3, 4], obj = 'cost', cut = False,
                 demands = {1: 30, 2: 20, 3: 20, 4: 20}, ac_lines = [(1, 2), (2,3), (3,4)], 
                 poss_ac_lines = [(1, 3), (1,4)], dc_lines = [], poss_dc_lines = [(3,1)], 
                 generation_cost = {1: 120}, printout = True,
                 max_new_ac = 0, max_new_dc = 0, label=datelabel, save = False)
# Out:
# Status: Optimal
# Objective Value: 10800.0
#
# Generation at Each Bus:
# Bus 1: 90.0 MW
#
# AC Line Flows:
# Line 1-2: 60.0 MW
# Line 2-3: 40.0 MW
# Line 3-4: 20.0 MW
# Line 1-3: 0.0 MW
# Line 1-4: 0.0 MW
#
# Voltage phases:
# Bus 1: 0.0 rads
# Bus 2: -0.04 rads
# Bus 3: -0.066666667 rads
# Bus 4: -0.08 rads

# %%
net = panda_DCOPF()
# Out:
# --- Generator Results ---
# 0    90.0
# Name: p_mw, dtype: float64
#
# --- Line Flow ---
#    p_from_mw
# 0       60.0
# 1       40.0
# 2       20.0
#
# --- Bus Voltage Angles (rad) ---
# 0    0.000000
# 1   -0.039954
# 2   -0.066645
# 3   -0.079997
# Name: va_degree, dtype: float64

# %% [markdown]
# # Now let's run a general test

# %%
def suggest_rand(pairs, bus_list, n=3):
    out = []
    for i in range(n):
        a,b = random.choice(bus_list),random.choice(bus_list)
        while (a,b) in pairs+out or (b,a) in pairs+out:
            a = random.choice(bus_list)
            b = random.choice(bus_list)
        out.append((a,b))
    return out

# %% [markdown]
# This will loop as follows:
# * generate a random network of variable node count, demands, generators, and generation capacity.
# * run the Pandapower DC OPF solver
# * run our pulp solver
# * compare results
# * if infeasible, each reports separately. Ideally they run or fall together

# %%
for i in range(15):
    print(f"\n## # Running Simulated Grid Number {i+1} # ##\n"*3)
    buses = np.arange(np.random.randint(6,13))
    n = len(buses)
    demands = {bus:np.random.randint(3,7)*30 for bus in buses}
    line_capacity = 1000
    line_expansion_cost = 1000
    obj = 'cost'
    cut = False
    ac_lines = suggest_rand([], buses,
                            n = np.random.randint(len(buses)+4, 2*len(buses)))
    poss_ac_lines = suggest_rand(ac_lines, buses, n = 1)
    poss_dc_lines = suggest_rand([], buses, n = 1)
    dc_lines = []
    susceptances = {line : np.random.randint(10,20)*100 for line in ac_lines + poss_ac_lines}  

    gen_buses = np.random.choice(buses, np.random.randint(n//5, n//3), replace = False)
    gen_capacity = {g : np.random.randint(3,7)*250* 
                           int(g in gen_buses) for g in buses}
    generation_cost = {g : np.random.randint(1,15)*10 for g in buses if g in gen_buses}
    printout = True
    max_new_ac = 0 
    max_new_dc = 0
    label=datelabel
    save = False
    
    try:
        net = panda_DCOPF(gen_capacity = gen_capacity, line_capacity = line_capacity, 
                     susceptances = susceptances, 
                     line_expansion_cost = line_expansion_cost, buses = buses, obj = 'cost', cut = False,
                     demands = demands, ac_lines = ac_lines, 
                     dc_lines = dc_lines,
                     generation_cost = generation_cost, printout = False)
        print('Panda Converged')
    except Exception:
        print('Panda Infeasible')
    
    out, prob = flow.ACDC_TEP_OPF(gen_capacity = gen_capacity, line_capacity = line_capacity, 
                     susceptances = susceptances, 
                     line_expansion_cost = line_expansion_cost, buses = buses, obj = 'cost', cut = False,
                     demands = demands, ac_lines = ac_lines, 
                     poss_ac_lines = poss_ac_lines, dc_lines = dc_lines, poss_dc_lines = poss_dc_lines, 
                     generation_cost = generation_cost, printout = False,
                     max_new_ac = 0, max_new_dc = 0, label=datelabel, save = False)
    if prob.status ==-1:
        print('Our Model Infeasible\n')
    else:
        print('Our Model Converged\n')
        flow_comp = pd.DataFrame({'PandaPower MW':list(net.res_line['p_from_mw'].values), 
                              'OurModel MW':list(out['ac_flow'].values())[:-1]})
        flow_comp['Error MW'] = flow_comp['PandaPower MW']-flow_comp['OurModel MW']
        phase_comp = pd.DataFrame({'PandaPower rads':list(net.res_bus['va_degree'].values*np.pi/180), 
                                  'OurModel rads':list(out['phase'].values())})
        phase_comp['Error rads'] = phase_comp['PandaPower rads']-phase_comp['OurModel rads']
        print("Our generators:")
        print([out['gen'][key] for key in out['gen'] if out['gen'][key] > 0],
              '\nPanda generators:')
        print(net.res_gen[['p_mw']])
        print("Line Flows:\n", flow_comp)
        print("Bus Phases:\n", phase_comp)
# Out:
# ## # Running Simulated Grid Number 1 # ##
#
# ## # Running Simulated Grid Number 1 # ##
#
# ## # Running Simulated Grid Number 1 # ##
#
# Panda Converged
# Our Model Converged
#
# Our generators:
# [86.446056, 1323.5539]
# Panda generators:
#           p_mw
# 0  1409.999979
# 1     0.000021
# Line Flows:
#      PandaPower MW  OurModel MW      Error MW
# 0        0.000000     0.000000  0.000000e+00
# 1        0.000000     0.000000  0.000000e+00
# 2      189.982075   306.833360 -1.168513e+02
# 3      489.981916  -716.720580  1.206702e+03
# 4      216.477925   216.795580 -3.176549e-01
# 5      173.521926   173.204420  3.175058e-01
# 6      180.000000   180.000000 -5.547938e-08
# 7       23.521981    23.204420  3.175612e-01
# 8        0.000000     0.000000  0.000000e+00
# 9     -119.999948  -120.000000  5.179800e-05
# 10     369.982002   486.833360 -1.168514e+02
# 11   -1229.996685    93.553944 -1.323551e+03
# 12    -560.017826  -443.166640 -1.168512e+02
# 13     -80.018009    36.833364 -1.168514e+02
# Bus Phases:
#     PandaPower rads  OurModel rads  Error rads
# 0        -1.494539      -0.335333   -1.159206
# 1        -1.257747       0.049489   -1.307235
# 2        -1.324621      -0.262936   -1.061685
# 3         0.000000       0.000000    0.000000
# 4        -1.504846      -0.420394   -1.084451
# 5        -0.873924       0.077962   -0.951886
# 6        -1.060452       0.455183   -1.515635
# 7        -1.532341      -0.443599   -1.088742
# 8        -1.397772      -0.229451   -1.168321
# 9        -1.626971      -0.523599   -1.103372
#
# ## # Running Simulated Grid Number 2 # ##
#
# ## # Running Simulated Grid Number 2 # ##
#
# ## # Running Simulated Grid Number 2 # ##
#
# Panda Converged
# Our Model Converged
#
# Our generators:
# [1380.0]
# Panda generators:
#           p_mw
# 0     0.000045
# 1  1379.999955
# Line Flows:
#      PandaPower MW  OurModel MW  Error MW
# 0      156.059727   156.137030 -0.077303
# 1        6.059727     6.137029 -0.077302
# 2       34.214370    33.993398  0.220972
# 3      219.743302   219.695830  0.047472
# 4       46.821061    46.524414  0.296647
# 5        0.000000     0.000000  0.000000
# 6       -8.927590    -8.827007 -0.100583
# 7     -300.259863  -300.438480  0.178617
# 8     -210.715560  -210.608280 -0.107280
# 9     -116.002341  -115.774670 -0.227671
# 10      42.965685    43.180554 -0.214869
# 11      75.543750    75.371737  0.172013
# 12     201.035386   200.517810  0.517576
# 13    -221.618905  -221.975960  0.357055
# 14      16.265211    16.094070  0.171141
# 15     113.940273   113.862970  0.077303
# 16      87.091702    87.181800 -0.090098
# 17      74.196970    74.167144  0.029826
# 18    -266.370241  -266.459470  0.089229
# Bus Phases:
#     PandaPower rads  OurModel rads  Error rads
# 0         0.000000       0.000000    0.000000
# 1        -0.032979      -0.033232    0.000253
# 2        -0.028062      -0.028328    0.000266
# 3        -0.260896      -0.257350   -0.003546
# 4        -0.088235      -0.088297    0.000062
# 5        -0.163418      -0.162465   -0.000953
# 6        -0.043762      -0.043961    0.000199
# 7        -0.256433      -0.252967   -0.003467
# 8         0.128936       0.133679   -0.004743
# 9        -0.111035      -0.111024   -0.000011
#
# ## # Running Simulated Grid Number 3 # ##
#
# ## # Running Simulated Grid Number 3 # ##
#
# ## # Running Simulated Grid Number 3 # ##
#
# Panda Converged
# Our Model Converged
#
# Our generators:
# [743.944, 306.056]
# Panda generators:
#          p_mw
# 0  999.999936
# 1   50.000064
# Line Flows:
#      PandaPower MW  OurModel MW      Error MW
# 0      109.132524   147.403220 -3.827070e+01
# 1        0.000000     0.000000  0.000000e+00
# 2      -27.631286   -77.549292  4.991801e+01
# 3      -92.368713   -42.450708 -4.991801e+01
# 4      179.999998   180.000000 -1.930581e-06
# 5        0.000000     0.000000  0.000000e+00
# 6       31.057808    52.575755 -2.151795e+01
# 7      387.821550   241.472270  1.463493e+02
# 8      121.057808   142.575760 -2.151795e+01
# 9     -150.000000  -150.000000  2.487756e-07
# 10     297.821554   151.472270  1.463493e+02
# 11     159.809667   100.021030  5.978864e+01
# 12     522.178374   412.471740  1.097066e+02
# Bus Phases:
#     PandaPower rads  OurModel rads  Error rads
# 0         0.000000       0.000000    0.000000
# 1        -0.493559      -0.355878   -0.137681
# 2        -0.557525      -0.408214   -0.149310
# 3        -0.529763      -0.360418   -0.169345
# 4        -0.310265      -0.201227   -0.109038
# 5        -0.469246      -0.285378   -0.183868
# 6        -0.674442      -0.523599   -0.150843
# 7        -0.406821      -0.317286   -0.089535
# 8        -0.603283      -0.497286   -0.105997
#
# ## # Running Simulated Grid Number 4 # ##
#
# ## # Running Simulated Grid Number 4 # ##
#
# ## # Running Simulated Grid Number 4 # ##
#
# Panda Converged
# Our Model Converged
#
# Our generators:
# [780.0, 750.0]
# Panda generators:
#          p_mw
# 0  780.000052
# 1  749.999948
# Line Flows:
#      PandaPower MW  OurModel MW      Error MW
# 0      -50.212000   -50.229596  1.759571e-02
# 1        0.000000     0.000000  0.000000e+00
# 2     -151.584734  -151.600220  1.548647e-02
# 3      266.706877   266.824970 -1.180934e-01
# 4        0.000000     0.000000  0.000000e+00
# 5       93.293071    93.175028  1.180434e-01
# 6      -36.494876   -36.595376  1.004997e-01
# 7      -90.000000   -90.000000  2.260160e-08
# 8        0.000000     0.000000  0.000000e+00
# 9      131.713038   131.687080  2.595811e-02
# 10    -228.287014  -228.312920  2.590623e-02
# 11      48.286962    48.312917 -2.595515e-02
# 12    -138.286962  -138.312920  2.595815e-02
# 13       0.000000     0.000000  0.000000e+00
# 14    -371.713038  -371.687080 -2.595805e-02
# 15    -181.708338  -181.574800 -1.335379e-01
# 16       9.787948     9.770404  1.754336e-02
# 17       0.000000     0.000000  0.000000e+00
# 18      31.708338    31.574805  1.335329e-01
# Bus Phases:
#      PandaPower rads  OurModel rads  Error rads
# 0         -0.158274      -0.163081    0.004807
# 1         -0.298393      -0.301394    0.003001
# 2         -0.150113      -0.154939    0.004826
# 3          0.000000       0.000000    0.000000
# 4         -0.331304      -0.333602    0.002298
# 5          0.028201       0.023794    0.004407
# 6         -0.228047      -0.232304    0.004257
# 7         -0.304237      -0.307304    0.003068
# 8         -0.087779      -0.092822    0.005043
# 9         -0.119603      -0.124442    0.004840
# 10        -0.066668      -0.071772    0.005104
#
# ## # Running Simulated Grid Number 5 # ##
#
# ## # Running Simulated Grid Number 5 # ##
#
# ## # Running Simulated Grid Number 5 # ##
#
# Panda Converged
# Our Model Converged
#
# Our generators:
# [379.56275, 1150.4372]
# Panda generators:
#           p_mw
# 0    29.999955
# 1     0.000052
# 2  1499.999994
# Line Flows:
#      PandaPower MW  OurModel MW      Error MW
# 0      -52.001316   -90.627239  3.862592e+01
# 1       81.441862    93.076249 -1.163439e+01
# 2     -244.354789  -136.359620 -1.079952e+02
# 3     -276.799796  -217.067700 -5.973210e+01
# 4      215.632399   179.158190  3.647421e+01
# 5       25.071638    42.221037 -1.714940e+01
# 6      149.999999   150.000000 -7.193793e-07
# 7      -75.127455   112.340230 -1.874677e+02
# 8       97.854048   105.544520 -7.690472e+00
# 9        0.000000     0.000000  0.000000e+00
# 10    -120.000000  -120.000000  4.680517e-07
# 11     237.360272   122.934450  1.144258e+02
# 12     -74.872590    87.222521 -1.620951e+02
# 13     -35.068465   -77.521505  4.245304e+01
# 14      52.145952    44.455475  7.690477e+00
# 15     -60.704089   -41.379226 -1.932486e+01
# 16     195.852731   164.917290  3.093544e+01
# 17     -34.645237   -80.708078  4.606284e+01
# 18   -1259.999980  -910.437250 -3.495627e+02
# 19       7.419218    12.635462 -5.216244e+00
# Bus Phases:
#      PandaPower rads  OurModel rads  Error rads
# 0          0.018715      -0.109887    0.128602
# 1          0.000000       0.000000    0.000000
# 2         -0.122069      -0.246250    0.124181
# 3         -0.061824      -0.194210    0.132386
# 4          0.924076       0.437884    0.486191
# 5          0.039502      -0.062411    0.101913
# 6         -0.000900      -0.145071    0.144171
# 7         -0.031620      -0.168059    0.136439
# 8          0.044230      -0.054514    0.098744
# 9         -0.002159      -0.132125    0.129965
# 10         0.195930       0.017800    0.178130
# 11         1.003854       0.523599    0.480256
#
# ## # Running Simulated Grid Number 6 # ##
#
# ## # Running Simulated Grid Number 6 # ##
#
# ## # Running Simulated Grid Number 6 # ##
#
# Panda Converged
# Our Model Converged
#
# Our generators:
# [560.0, 1000.0]
# Panda generators:
#          p_mw
# 0  560.000042
# 1  999.999958
# Line Flows:
#      PandaPower MW  OurModel MW      Error MW
# 0        0.000000     0.000000  0.000000e+00
# 1       -5.095020   -10.138506  5.043486e+00
# 2     -150.000000  -150.000000  2.854907e-08
# 3     -435.094978  -440.138510  5.043532e+00
# 4      196.235949   193.170170  3.065779e+00
# 5      -12.598508   -10.951557 -1.646951e+00
# 6      105.391013   106.063360 -6.723472e-01
# 7     -180.000000  -180.000000  4.703793e-11
# 8      238.669073   236.691320  1.977753e+00
# 9     -384.904980  -379.861490 -5.043490e+00
# 10     -33.637441   -32.218612 -1.418829e+00
# 11       0.000000     0.000000  0.000000e+00
# 12    -144.904980  -139.861490 -5.043490e+00
# 13    -118.852535  -117.774200 -1.078335e+00
# 14     105.207551   104.980480  2.270711e-01
# 15     -11.155008   -12.800907  1.645899e+00
# 16    -239.703965  -244.075150  4.371185e+00
# Bus Phases:
#      PandaPower rads  OurModel rads  Error rads
# 0          0.000000       0.000000    0.000000
# 1         -0.172053      -0.175609    0.003556
# 2         -0.288533      -0.286561   -0.001972
# 3         -0.191943      -0.194561    0.002618
# 4          0.301927       0.295581    0.006347
# 5         -0.121185      -0.124574    0.003389
# 6         -0.038074      -0.042987    0.004914
# 7         -0.028552      -0.035010    0.006458
# 8         -0.004830      -0.010139    0.005308
# 9          0.079390       0.072133    0.007257
# 10        -0.184826      -0.186561    0.001735
#
# ## # Running Simulated Grid Number 7 # ##
#
# ## # Running Simulated Grid Number 7 # ##
#
# ## # Running Simulated Grid Number 7 # ##
#
# Panda Infeasible
# Our Model Infeasible
#
#
# ## # Running Simulated Grid Number 8 # ##
#
# ## # Running Simulated Grid Number 8 # ##
#
# ## # Running Simulated Grid Number 8 # ##
#
# Panda Converged
# Our Model Converged
#
# Our generators:
# [186.84681, 1073.1532]
# Panda generators:
#           p_mw
# 0    10.000056
# 1  1249.999944
# Line Flows:
#      PandaPower MW  OurModel MW      Error MW
# 0        0.000000     0.000000  0.000000e+00
# 1      117.012175     4.396881  1.126153e+02
# 2     -338.980454  -256.870270 -8.211018e+01
# 3     -112.987769   -48.756306 -6.423146e+01
# 4     -512.629740  -431.731210 -8.089853e+01
# 5       13.952910    41.062024 -2.710911e+01
# 6        0.000000     0.000000  0.000000e+00
# 7      -22.987769    41.243694 -6.423146e+01
# 8       98.389750    84.551702  1.383805e+01
# 9      -90.000000   -90.000000  7.014927e-08
# 10     587.370204   491.421970  9.594823e+01
# 11    -234.972400  -167.344940 -6.762746e+01
# 12       0.000000     0.000000  0.000000e+00
# 13     166.047090   138.937980  2.710911e+01
# 14    -379.999944  -203.153190 -1.768468e+02
# Bus Phases:
#     PandaPower rads  OurModel rads  Error rads
# 0         0.441048       0.215219    0.225828
# 1         0.000000       0.000000    0.000000
# 2         0.374601       0.150934    0.223667
# 3         0.296317       0.099438    0.196879
# 4         0.500118       0.264956    0.235163
# 5         0.304492       0.122250    0.182242
# 6         0.789290       0.523599    0.265692
# 7         0.012269      -0.022913    0.035182
# 8         0.071473       0.002748    0.068725
#
# ## # Running Simulated Grid Number 9 # ##
#
# ## # Running Simulated Grid Number 9 # ##
#
# ## # Running Simulated Grid Number 9 # ##
#
# Panda Converged
# Our Model Converged
#
# Our generators:
# [30.0, 750.0, 750.0]
# Panda generators:
#          p_mw
# 0   30.000026
# 1  749.999989
# 2  749.999985
# Line Flows:
#      PandaPower MW  OurModel MW      Error MW
# 0      -66.213582   -65.233750 -9.798320e-01
# 1      209.970027   210.360570 -3.905429e-01
# 2      -13.214883   -13.409461  1.945776e-01
# 3      -90.734793   -90.760936  2.614254e-02
# 4      -70.679304   -70.974409  2.951051e-01
# 5      -76.817858   -76.898980  8.112230e-02
# 6      -39.343421   -39.895809  5.523880e-01
# 7      -35.218220   -35.087667 -1.305530e-01
# 8     -335.240327  -335.607480  3.671526e-01
# 9     -272.745355  -272.600490 -1.448646e-01
# 10     167.146381   165.403730  1.742651e+00
# 11    -120.000000  -120.000000  1.421085e-14
# 12      27.527135    27.512821  1.431355e-02
# 13     -16.418059   -16.529630  1.115706e-01
# 14      78.087475    78.316910 -2.294355e-01
# 15     -56.397026   -56.510480  1.134543e-01
# 16      49.861777    48.364789  1.496988e+00
# 17      59.157437    59.621445 -4.640078e-01
# 18       0.000000     0.000000  0.000000e+00
# 19     244.897884   246.027730 -1.129846e+00
# 20      16.050323    15.829603  2.207202e-01
# 21      62.569104    61.787280  7.818244e-01
# Bus Phases:
#      PandaPower rads  OurModel rads  Error rads
# 0         -0.040999      -0.040771   -0.000228
# 1          0.000000       0.000000    0.000000
# 2          0.009040       0.009183   -0.000143
# 3         -0.039640      -0.039134   -0.000506
# 4          0.003375       0.003588   -0.000213
# 5         -0.071235      -0.070378   -0.000857
# 6          0.021809       0.021930   -0.000120
# 7          0.195703       0.195632    0.000071
# 8         -0.051736      -0.051324   -0.000412
# 9          0.164924       0.165404   -0.000480
# 10        -0.009696      -0.009391   -0.000305
# 11        -0.034370      -0.034326   -0.000043
#
# ## # Running Simulated Grid Number 10 # ##
#
# ## # Running Simulated Grid Number 10 # ##
#
# ## # Running Simulated Grid Number 10 # ##
#
# Panda Converged
# Our Model Converged
#
# Our generators:
# [1110.0]
# Panda generators:
#      p_mw
# 0  1110.0
# Line Flows:
#      PandaPower MW  OurModel MW  Error MW
# 0      234.082230   233.982910  0.099320
# 1       42.581997    42.428219  0.153778
# 2       48.279867    48.245847  0.034020
# 3       33.631307    33.507354  0.123953
# 4      254.698731   254.681380  0.017351
# 5       -5.802363    -5.737064 -0.065300
# 6        0.000000     0.000000  0.000000
# 7      102.268350   102.414840 -0.146490
# 8      -46.869787   -46.911093  0.041306
# 9      -47.731650   -47.585159 -0.146491
# 10     248.637042   248.907490 -0.270448
# 11     192.581997   192.428220  0.153777
# Bus Phases:
#     PandaPower rads  OurModel rads  Error rads
# 0        -0.189318      -0.190450    0.001132
# 1        -0.157937      -0.159176    0.001238
# 2        -0.176719      -0.177791    0.001072
# 3        -0.146625      -0.148022    0.001396
# 4        -0.237412      -0.238035    0.000624
# 5         0.000000       0.000000    0.000000
# 6        -0.154705      -0.155989    0.001283
#
# ## # Running Simulated Grid Number 11 # ##
#
# ## # Running Simulated Grid Number 11 # ##
#
# ## # Running Simulated Grid Number 11 # ##
#
# Panda Converged
# Our Model Converged
#
# Our generators:
# [505.32951, 784.67049]
# Panda generators:
#           p_mw
# 0    40.000072
# 1  1249.999928
# Line Flows:
#      PandaPower MW  OurModel MW    Error MW
# 0     -115.817875   -86.636545  -29.181330
# 1      210.246660   277.996150  -67.749490
# 2      -86.064519  -124.632700   38.568181
# 3     -111.877135   -83.674607  -28.202528
# 4     -278.643762  -224.718130  -53.925632
# 5       25.817879    -3.363455   29.181334
# 6     1159.996577   694.670490  465.326087
# 7        0.000000     0.000000    0.000000
# 8      309.438832   186.103440  123.335392
# 9     -331.916926   -43.848914 -288.068012
# 10     149.999830   150.000000   -0.000170
# 11     -17.941654   -28.307304   10.365650
# 12      85.291564   100.649170  -15.357606
# 13      18.329522   -91.182275  109.511797
# 14     102.058326    91.692696   10.365630
# Bus Phases:
#     PandaPower rads  OurModel rads  Error rads
# 0         0.013631      -0.075985    0.089616
# 1        -0.093717      -0.146314    0.052596
# 2         0.108136      -0.051542    0.159678
# 3         0.199506       0.027406    0.172101
# 4        -0.141488      -0.219627    0.078139
# 5         0.000000       0.000000    0.000000
# 6        -0.059724      -0.159860    0.100136
# 7        -0.080482      -0.148182    0.067701
# 8        -0.156521      -0.243217    0.086695
# 9         1.116335       0.523599    0.592736
#
# ## # Running Simulated Grid Number 12 # ##
#
# ## # Running Simulated Grid Number 12 # ##
#
# ## # Running Simulated Grid Number 12 # ##
#
# Panda Converged
# Our Model Infeasible
#
#
# ## # Running Simulated Grid Number 13 # ##
#
# ## # Running Simulated Grid Number 13 # ##
#
# ## # Running Simulated Grid Number 13 # ##
#
# Panda Converged
# Our Model Converged
#
# Our generators:
# [1000.0, 230.0]
# Panda generators:
#          p_mw
# 0  999.999833
# 1  230.000167
# Line Flows:
#      PandaPower MW  OurModel MW      Error MW
# 0      334.728998   334.155420  5.735778e-01
# 1      -94.237140   -93.989155 -2.479848e-01
# 2      -57.525261   -57.334998 -1.902632e-01
# 3      -33.848123   -34.366489  5.183655e-01
# 4        0.000000     0.000000  0.000000e+00
# 5        5.892686     5.883767  8.919000e-03
# 6      -94.858859   -95.694248  8.353891e-01
# 7     -274.260099  -274.516820  2.567207e-01
# 8      -62.966597   -62.831270 -1.353268e-01
# 9      -21.140717   -21.284963  1.442461e-01
# 10    -146.151877  -145.633510 -5.183665e-01
# 11    -171.010903  -171.327760  3.168573e-01
# 12       0.000000     0.000000  0.000000e+00
# 13     -61.655546   -61.894613  2.390666e-01
# 14     -19.355356   -19.433146  7.778975e-02
# 15    -180.000000  -180.000000  4.006185e-08
# Bus Phases:
#     PandaPower rads  OurModel rads  Error rads
# 0         0.000000       0.000000    0.000000
# 1        -0.254121      -0.258323    0.004202
# 2        -0.287140      -0.290899    0.003759
# 3        -0.233997      -0.238682    0.004685
# 4        -0.386583      -0.387017    0.000434
# 5        -0.082429      -0.086995    0.004566
# 6        -0.270570      -0.274517    0.003947
# 7        -0.292137      -0.295802    0.003665
# 8        -0.115277      -0.121361    0.006085
#
# ## # Running Simulated Grid Number 14 # ##
#
# ## # Running Simulated Grid Number 14 # ##
#
# ## # Running Simulated Grid Number 14 # ##
#
# Panda Converged
# Our Model Infeasible
#
#
# ## # Running Simulated Grid Number 15 # ##
#
# ## # Running Simulated Grid Number 15 # ##
#
# ## # Running Simulated Grid Number 15 # ##
#
# Panda Converged
# Our Model Converged
#
# Our generators:
# [750.0, 660.0]
# Panda generators:
#         p_mw
# 0  749.99995
# 1  660.00005
# Line Flows:
#      PandaPower MW  OurModel MW      Error MW
# 0     -152.649672  -152.850480  2.008082e-01
# 1       52.242982    52.205680  3.730232e-02
# 2        9.726167     9.797891 -7.172441e-02
# 3     -154.185892  -154.305650  1.197585e-01
# 4      175.578906   175.523330  5.557611e-02
# 5     -140.683063  -140.599470 -8.359287e-02
# 6       50.673115    50.633375  3.974044e-02
# 7       56.664076    56.682350 -1.827379e-02
# 8       31.363390    31.368996 -5.605653e-03
# 9       35.266113    35.253793  1.232019e-02
# 10      45.166487    45.258270 -9.178250e-02
# 11    -147.585480  -147.320540 -2.649403e-01
# 12     -49.017473   -49.031030  1.355695e-02
# 13     -90.000000   -90.000000  1.222347e-09
# 14     -65.608685   -65.767498  1.588128e-01
# 15      15.540139    15.522141  1.799786e-02
# 16     -24.160397   -24.108355 -5.204206e-02
# 17     157.044226   156.950690  9.353600e-02
# 18     -43.096471   -43.108864  1.239321e-02
# 19      63.194166    63.088036  1.061295e-01
# Bus Phases:
#      PandaPower rads  OurModel rads  Error rads
# 0         -0.124462      -0.124941    0.000479
# 1          0.000000       0.000000    0.000000
# 2         -0.104891      -0.105229    0.000338
# 3         -0.169004      -0.169120    0.000116
# 4         -0.152736      -0.152850    0.000114
# 5         -0.179407      -0.179468    0.000060
# 6         -0.140051      -0.140278    0.000227
# 7         -0.068635      -0.068691    0.000056
# 8         -0.187674      -0.187665   -0.000009
# 9         -0.125126      -0.125374    0.000248
# 10        -0.160880      -0.161015    0.000136
